# %%
import glob

working_dir_path = '/gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/*/unrelaxed_model_*.pdb'
temp = glob.glob(working_dir_path)
print(temp)
# Out:
# ['/gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1046s1/unrelaxed_model_5.pdb', '/gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1046s1/unrelaxed_model_4.pdb', '/gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1046s1/unrelaxed_model_2.pdb', '/gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1046s1/unrelaxed_model_1.pdb', '/gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1046s1/unrelaxed_model_3.pdb', '/gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1096/unrelaxed_model_5.pdb', '/gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1096/unrelaxed_model_4.pdb', '/gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1096/unrelaxed_model_2.pdb', '/gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1096/unrelaxed_mo
# ...

# %%
print(len(temp))
temp += glob.glob('/gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_full_db_uniref90_2020_02/*/unrelaxed_model_*.pdb')
print(len(temp))
# Out:
# 160
# 210

# %%
for pdb in temp:
    print(pdb)
# Out:
# /gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1046s1/unrelaxed_model_5.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1046s1/unrelaxed_model_4.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1046s1/unrelaxed_model_2.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1046s1/unrelaxed_model_1.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1046s1/unrelaxed_model_3.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1096/unrelaxed_model_5.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1096/unrelaxed_model_4.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1096/unrelaxed_model_2.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_extra_benchmark/casp14/af_reduced_db/T1096/unrelaxed_model_1.pdb
# ...

# %%
temp = '/gpfs/alpine/world-shared/bif135/alphafold_onsummit/alphafold_test/casp14/af_reduced_db/*/unrelaxed_model_*.pdb'
pdbs = glob.glob(temp)
pdbs.sort()
for pdb in pdbs:
    print(pdb)
# Out:
# /gpfs/alpine/world-shared/bif135/alphafold_onsummit/alphafold_test/casp14/af_reduced_db/T1027/unrelaxed_model_1.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_onsummit/alphafold_test/casp14/af_reduced_db/T1027/unrelaxed_model_2.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_onsummit/alphafold_test/casp14/af_reduced_db/T1027/unrelaxed_model_3.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_onsummit/alphafold_test/casp14/af_reduced_db/T1027/unrelaxed_model_4.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_onsummit/alphafold_test/casp14/af_reduced_db/T1027/unrelaxed_model_5.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_onsummit/alphafold_test/casp14/af_reduced_db/T1029/unrelaxed_model_1.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_onsummit/alphafold_test/casp14/af_reduced_db/T1029/unrelaxed_model_2.pdb
# /gpfs/alpine/world-shared/bif135/alphafold_onsummit/alphafold_test/casp14/af_reduced_db/T1029/unrelaxed_model_3.pdb
# ...
